# %%
# !pip install beautifulsoup4
# !pip install sys
# !pip install io
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.3)
# Collecting sys
#   ERROR: Could not find a version that satisfies the requirement sys (from versions: none)
# ERROR: No matching distribution found for sys
# Collecting io
#   ERROR: Could not find a version that satisfies the requirement io (from versions: none)
# ERROR: No matching distribution found for io

# %%
#라이브러리 읽어 들이기
from bs4 import BeautifulSoup
import  urllib.request as req 
from urllib.error import HTTPError,URLError
import csv

# -*- coding:utf-8 -*-

# %%
url = "https://solved.ac/problems/tags?page=1"
    
try:
    headers = {'User-Agent':'Chrome/66.0.3359.181'}
    rew = req.Request(url,headers=headers)
    html = req.urlopen(rew)
    
except HTTPError as e:
    err = e.read()
    code = e.getcode()
source = html.read()
html.close()
soup = BeautifulSoup(source,"html.parser")

# %%
body = soup.select('body')
div1 = body[0].select('.StickyTable__Row-akg1ak-2')
div2 = body[0].select('.Paginationstyles__PaginationWrapper-gesjo3-2')
print(div2)
print(div1)
# Out:
# [<div class="Paginationstyles__PaginationWrapper-gesjo3-2 ifBhdB"><div class="Paginationstyles__PageIndicator-gesjo3-0 Paginationstyles__PageIndicatorCurrent-gesjo3-1 dBAApK">1</div><a href="?page=2"><div class="Paginationstyles__PageIndicator-gesjo3-0 dxDiFC">2</div></a><a href="?page=3"><div class="Paginationstyles__PageIndicator-gesjo3-0 dxDiFC">3</div></a><a href="?page=5"><div class="Paginationstyles__PageIndicator-gesjo3-0 dxDiFC">5</div></a><a href="?page=6"><div class="Paginationstyles__PageIndicator-gesjo3-0 dxDiFC">6</div></a></div>]
# [<div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell" style="width:20%">태그</div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell" style="width:10%">미해결</div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell" style="width:10%">해결</div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell" style="width:10%">전체</div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell" style="width:50%;min-width:200px">진행도</div></div>, <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell" style="word-break:break-all"><a href="/problems/tags/math" style="text-decoration:none">수학</a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><a href="/problems/tags/math/unsolved" style="text-decoration:none"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">0</div></a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><a href="/problems/tags/math/solved" style="text-decoration:none"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">0</div></a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><a href="/problems/tags/math" style="text-decoration:none"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">1,633</div></a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="ProgressBarstyles__ProgressBarStyle-sc-8ahwco-0 cfxQyX"><div style="position:relative;height:100%;width:100%;background:#000;overflow:hidden"><div class="ProgressBarstyles__ProgressBarInsets-sc-8ahwco-1 ProgressBarstyles__ThemedInsets-sc-8ahwco-4 jhRISH" style="width:NaN%"></div><div class="ProgressBarstyles__ProgressBarMask-sc-8ahwco-3 khjGZM" max="1633" style="background:black"></div></div></div></div></div>, <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell" style="word-break:break-all"><a href="/problems/tags/dp" style="text-decoration:none">다이나믹 프로그래밍</a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><a href="/problems/tags/dp/unsolved" style="text-decoration:none"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">0</div></a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><a href="/problems/tags/dp/solved" style="text-decoration:none"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">0</div></a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><a href="/problems/tags/dp" style="text-decoration:none"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">1,382</div></a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="ProgressBarstyles__ProgressBarStyle-sc-8ahwco-0 cfxQyX"><div style="position:relative;height:100%;width:84.62951622780159%;background:#000;overflow:hidden"><div class="ProgressBarstyles__ProgressBarInsets-sc-8ahwco-1 ProgressBarstyles__ThemedInsets-sc-8ahwco-4 jhRISH" style="width:NaN%"></div><div class="ProgressBarstyles__ProgressBarMask-sc-8ahwco-3 eCaxTB" max="1382" style="background:black"></div></div></div></div></div>, <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell" style="word-break:break-all"><a href="/problems/tags/implementation" style="text-decoration:none">구현</a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><a href="/problems/tags/implementation/unsolved" style="text-decoration:none"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">0</div></a></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><a href="/problems/tags/implementation/solved" style="text-decoration:none"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">0</div></a></div><div class="StickyTable__Cell-akg1ak-1  ...

# %%
tag = []
tag_url = []
for tag_page in range(1,7):
    url = "https://solved.ac/problems/tags?page="+str(tag_page)
        
    try:
        headers = {'User-Agent':'Chrome/66.0.3359.181'}
        rew = req.Request(url,headers=headers)
        html = req.urlopen(rew)
        
    except HTTPError as e:
        err = e.read()
        code = e.getcode()
    source = html.read()
    html.close()
    soup = BeautifulSoup(source,"html.parser")
    body = soup.select('body')
    div1 = body[0].select('.StickyTable__Row-akg1ak-2')
    for i in range(1, len(div1)):
        div_tag = div1[i].select('a')[0]
        print(div_tag['href'])
        tag_url.append(div_tag['href'])
        div2 = div1[i].select('a')
        tag.append(div2[0].text)
        print(div2[0].text)
# Out:
# /problems/tags/math
# 수학
# /problems/tags/dp
# 다이나믹 프로그래밍
# /problems/tags/implementation
# 구현
# /problems/tags/graphs
# 그래프 이론
# /problems/tags/data_structures
# 자료 구조
# /problems/tags/graph_traversal
# 그래프 탐색
# /problems/tags/greedy
# 그리디 알고리즘
# /problems/tags/string
# 문자열
# /problems/tags/bruteforcing
# 브루트포스 알고리즘
# /problems/tags/segtree
# 세그먼트 트리
# /problems/tags/trees
# 트리
# /problems/tags/binary_search
# 이분 탐색
# /problems/tags/sorting
# 정렬
# /problems/tags/geometry
# 기하학
# /problems/tags/number_theory
# 정수론
# /problems/tags/bfs
# 너비 우선 탐색
# /problems/tags/arithmetic
# 사칙연산
# /problems/tags/combinatorics
# 조합론
# /problems/tags/dijkstra
# 다익스트라
# /problems/tags/dfs
# 깊이 우선 탐색
# /problems/tags/prefix_sum
# 누적 합
# /problems/tags/simulation
# 시뮬레이션
# /problems/tags/bitmask
# 비트마스킹
# /problems/tags/divide_and_conquer
# 분할 정복
# /problems/tags/disjoint_set
# 분리 집합
# /problems/tags/backtracking
# 백트래킹
# /problems/tags/flow
# 최대 유량
# /problems/tags/sweeping
# 스위핑
# /problems/tags/constructive
# 구성적
# /problems/tags/dp_tree
# 트리에서의 다이나믹 프로그래밍
# /problems/tags/stack
# 스택
# /problems/tags/ad_hoc
# 애드 혹
# /problems/tags/priority_queue
# 우선순위 큐
# /problems/tags/parsing
# 파싱
# /problems/tags/dp_bitfield
# 비트필드를 이용한 다이나믹 프로그래밍
# /problems/tags/lazyprop
# 느리게 갱신되는 세그먼트 트리
# /problems/tags/exponentiation_by_squaring
# 분할 정복을 이용한 거듭제곱
# /problems/tags/offline_queries
# 오프라인 쿼리
# /problems/tags/game_theory
# 게임 이론
# /problems/tags/two_pointer
# 두 포인터
# /problems/tags/bipartite_matching
# 이분 매칭
# /problems/tags/primality_test
# 소수 판정
# /problems/tags/tree_set
# 트리를 사용한 집합과 맵
# /problems/tags/case_work
# Case work
# /problems/tags/mst
# 최소 스패닝 트리
# /problems/tags/arbitrary_precision
# 임의 정밀도 / 큰 수 연산
# /problems/tags/lca
# 최소 공통 조상
# /problems/tags/scc
# 강한 연결 요소
# /problems/tags/convex_hull
# 볼록 껍질
# /problems/tags/hashing
# 해싱
# /problems/tags/sieve
# 에라토스테네스의 체
# /problems/tags/floyd_warshall
# 플로이드–와샬
# /problems/tags/recursion
# 재귀
# /problems/tags/linear_algebra
# 선형대수학
# /problems/tags/topological_sorting
# 위상 정렬
# /problems/tags/fft
# 고속 푸리에 변환
# /problems/tags/trie
# 트라이
# /problems/tags/inclusion_and_exclusion
# 포함 배제의 원리
# /problems/tags/kmp
# KMP
# /problems/tags/cht
# 볼록 껍질을 이용한 최적화
# /problems/tags/hash_set
# 해시를 사용한 집합과 맵
# /problems/tags/mcmf
# 최소 비용 최대 유량
# /problems/tags/suffix_array
# 접미사 배열과 LCP 배열
# /problems/tags/mitm
# 중간에서 만나기
# /problems/tags/sparse_array
# 희소 배열
# /problems/tags/euclidean
# 유클리드 호제법
# /problems/tags/lis
# 가장 긴 증가하는 부분 수열: O(n log n)
# /problems/tags/sqrt_decomposition
# 제곱근 분할법
# /problems/tags/sprague_grundy
# 스프라그–그런디 정리
# /problems/tags/deque
# 덱
# /problems/tags/coordinate_compression
# 값 / 좌표 압축
# /problems/tags/smaller_to_larger
# 작은 집합에서 큰 집합으로 합치는 테크닉
# /problems/tags/line_intersection
# 선분 교차 판정
# /problems/tags/knapsack
# 배낭 문제
# /problems/tags/2_sat
# 2-SAT
# /problems/tags/sliding_window
# 슬라이딩 윈도우
# /problems/tags/mfmc
# 최대 유량 최소 컷 정리
# /problems/tags/hld
# Heavy-light 분할
# /problems/tags/ternary_search
# 삼분 탐색
# /problems/tags/randomization
# 무작위화
# /problems/tags/precomputation
# 런타임 전의 전처리
# /problems/tags/gaussian_elimination
# 가우스 소거법
# /problems/tags/geometry_3d
# 3차원 기하학
# /problems/tags/articulation
# 단절점과 단절선
# /problems/tags/centroid
# 센트로이드 분할
# /problems/tags/heuristics
# 휴리스틱
# /problems/tags/euler_tour_technique
# 오일러 경로 테크닉
# /problems/tags/mo
# Mo's
# /problems/tags/pst
# 퍼시스턴트 세그먼트 트리
# /problems/tags/probability
# 확률론
# /problems/tags/calculus
# 미적분학
# /problems/tags/pbs
# 병렬 이분 탐색
# /problems/tags/cactus
# 선인장
# /problems/tags/crt
# 중국인의 나머지 정리
# /problems/tags/divide_and_conquer_optimization
# 분할 정복을 사용한 최적화
# /problems/tags/bellman_ford
# 벨만–포드
# /problems/tags/queue
# 큐
# /problems/tags/eulerian_path
# 오일러 경로
# /problems/tags/bitset
# 비트 집합
# /problems/tags/splay_tree
# 스플레이 트리
# /problems/tags/rabin_karp
# 라빈–카프
# /problems/tags/biconnected_component
# 이중 연결 요소
# /problems/tags/aho_corasick
# 아호-코라식
# /problems/tags/extended_euclidean
# 확장 유클리드 호제법
# /problems/tags/berlekamp_massey
# 벌래캠프–매시
# /problems/tags/planar_graph
# 평면 그래프
# /problems/tags/parametric_search
# 매개 변수 탐색
# /problems/tags/rotating_calipers
# 회전하는 캘리퍼스
# /problems/tags/physics
# 물리학
# /problems/tags/multi_segtree
# 다차원 세그먼트 트리
# /problems/tags/mobius_inversion
# 뫼비우스 반전 공식
# /problems/tags/euler_characteristic
# 오일러 지표 (χ=V-E+F)
# /problems/tags/regex
# 정규 표현식
# /problems/tags/linear_programming
# 선형 계획법
# /problems/tags/dp_connection_profile
# 커넥션 프로파일을 이용한 다이나믹 프로그래밍
# /problems/tags/numerical_analysis
# 수치해석
# /problems/tags/permutation_cycle_decomposition
# 순열 사이클 분할
# /problems/tags/manacher
# 마나허
# /problems/tags/point_in_convex_polygon
# 볼록 다각형 내부의 점 판정
# /problems/tags/link_cut_tree
# 링크/컷 트리
# /problems/tags/dp_deque
# 덱을 이용한 다이나믹 프로그래밍
# /problems/tags/euler_phi
# 오일러 토션트 함수
# /problems/tags/merge_sort_tree
# 머지 소트 트리
# /problems/tags/interpreter
# 인터프리터
# /problems/tags/alien
# Alien 트릭
# /problems/tags/tsp
# 외판원 순회 문제
# /problems/tags/slope_trick
# 함수 개형을 이용한 최적화
# /problems/tags/polygon_area
# 다각형의 넓이
# /problems/tags/burnside
# 번사이드 보조정리
# /problems/tags/flt
# 페르마의 소정리
# /problems/tags/offline_dynamic_connectivity
# 오프라인 동적 연결성 판정
# /problems/tags/hall
# 홀의 결혼 정리
# /problems/tags/hungarian
# 헝가리안
# /problems/tags/pollard_rho
# 폴라드 로
# /problems/tags/z
# Z
# /problems/tags/kitamasa
# 키타마사
# /problems/tags/tree_isomorphism
# 트리 동형 사상
# /problems/tags/modular_multiplicative_inverse
# 모듈로 곱셈 역원
# /problems/tags/monotone_queue_optimization
# 단조 큐를 이용한 최적화
# /problems/tags/0_1_bfs
# 0-1 너비 우선 탐색
# /problems/tags/stoer_wagner
# 스토어–바그너
# /problems/tags/knuth
# 크누스 최적화
# /problems/tags/matroid
# 매트로이드
# /problems/tags/bidirectional_search
# 양방향 탐색
# /problems/tags/linked_list
# 연결 리스트
# /problems/tags/linearity_of_expectation
# 기댓값의 선형성
# /problems/tags/general_matching
# 일반적인 매칭
# /problems/tags/miller_rabin
# 밀러–라빈 소수 판별법
# /problems/tags/palindrome_tree
# 회문 트리
# /problems/tags/point_in_non_convex_polygon
# 오목 다각형 내부의 점 판정
# /problems/tags/pythagoras
# 피타고라스 정리
# /problems/tags/dominator_tree
# 도미네이터 트리
# /problems/tags/discrete_log
# 이산 로그
# /problems/tags/min_enclosing_circle
# 최소 외접원
# /problems/tags/voronoi
# 보로노이 다이어그램
# /problems/tags/hirschberg
# 히르쉬버그
# /problems/tags/duality
# 쌍대성
# /problems/tags/directed_mst
# 유향 최소 신장 트리
# /problems/tags/lucas
# 루카스 정리
# /problems/tags/discrete_sqrt
# 이산 제곱근
# /problems/tags/majority_vote
# 보이어–무어 다수결 투표
# /problems/tags/statistics
# 통계학
# /problems/tags/delaunay
# 델로네 삼각분할
# /problems/tags/rb_tree
# 레드-블랙 트리
# /problems/tags/top_tree
# 탑 트리
# /problems/tags/bayes
# 베이즈 정리
# /problems/tags/geometry_hyper
# 4차원 이상의 기하학
# /problems/tags/discrete_kth_root
# 이산 k제곱근
# /problems/tags/rope
# 로프
# /problems/tags/dancing_links
# 춤추는 링크
# /problems/tags/knuth_x
# 크누스 X
# /problems/tags/dual_graph
# 쌍대 그래프

# %%
print(len(tag))
print(len(tag_url))
# Out:
# 172
# 172

# %%
#f = open("problem.csv", "w")
f = open('problem.csv','w', encoding='utf-8-sig', newline='')
f.write("문제번호,링크,난이도,분류,해결,평균시도")
wr = csv.writer(f)
for tag_num in range(0,len(tag)):
    url = "https://solved.ac"+tag_url[tag_num]
    try:
        headers = {'User-Agent':'Chrome/66.0.3359.181'}
        rew = req.Request(url,headers=headers)
        html = req.urlopen(rew)
    
    except HTTPError as e:
        err = e.read()
        code = e.getcode()
    source = html.read()
    html.close()
    soup = BeautifulSoup(source,"html.parser")
    body = soup.select('body')
    page = body[0].select('.Paginationstyles__PageIndicator-gesjo3-0')
    last_page = page[len(page)-1].text
    for page_num in range(1, (int)(last_page)+1):
        url = url + "?sort=level&direction=asc&page="+ str(page_num)
        div1 = body[0].select('.StickyTable__Row-akg1ak-2')
        for i in range(1, len(div1)): 
            list = []
            div2 = div1[i]
            div3 = div2.select('a')
            #번호
            div6 = div3[0].select('span')[0]
            list.append(div6.text)
            
            #링크
            div4 = div3[0]['href']
            list.append(div4)
            
            #난이도
            div5 = div3[0].select('img')[0]['alt']
            list.append(div5)
            
            #문제이름
            div7 = div3[1].select('span')[0]
            list.append(div7.text)
           
            #분류
            list.append(tag[tag_num])

            div8 = div2.select('.TabularFigures__TabularFiguresStyle-ved8ab-0')
            num = div8[0].text.replace(",","")
            list.append((int)(num)) #해결
            list.append((float)(div8[1].text)) #평균시도
    
  
            wr.writerow(list)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-164-09402ba80bf2> in <module>
#      51
#      52
# ---> 53             wr.writerow(list)
#
# PermissionError: [Errno 13] Permission denied

# %%
url = "https://solved.ac/problems/tags/math"
    
try:
    headers = {'User-Agent':'Chrome/66.0.3359.181'}
    rew = req.Request(url,headers=headers)
    html = req.urlopen(rew)
    
except HTTPError as e:
    err = e.read()
    code = e.getcode()
source = html.read()
html.close()
soup = BeautifulSoup(source,"html.parser")

# %%
body = soup.select('body')
print(body)
# Out:
# [<body><div id="__next"><div><div class="Headerstyles__TopBarContainer-aisgi1-0 eTeBIf"><div class="Headerstyles__TopBar-aisgi1-1 Headerstyles__NavigationBig-aisgi1-2 ZDBNs"><nav><a href="/"><div class="Headerstyles__Logo-aisgi1-5 bgryKu"></div><span class="Headerstyles__Version-aisgi1-6 bAlNbY">solved.ac</span></a><ul class="Headerstyles__Sitemap-aisgi1-7 cVbtKi"><li><span>문제</span><ul style="column-count:1"><li><a href="/problems/level">레벨</a></li><li><a href="/problems/tags">태그</a></li><li><a href="/search">검색</a></li><li><a href="/class">CLASS</a></li><li><a href="/problems/calculate">경험치 계산기</a></li></ul></li><li><span>기여</span><ul style="column-count:1"><li><a href="/guideline">가이드라인</a></li></ul></li><li><span>랭킹</span><ul style="column-count:1"><li><a href="/ranking/tier">티어</a></li><li><a href="/ranking/class">CLASS</a></li><li><a href="/ranking/contribution">기여</a></li><li><a href="/ranking/o">단체</a></li></ul></li><li><span>정보</span><ul style="column-count:1"><li><a href="/faq">자주 묻는 질문</a></li><li><a href="/rules">이용 규칙</a></li><li><a href="/redeem">코드 교환</a></li><li><a href="/slack">Slack</a></li><li><a href="/update_log">업데이트 로그</a></li></ul></li><li><i class="material-icons">search</i></li></ul></nav><div class="Headerstyles__TopBarInformation-aisgi1-19 dBCqXq"><div><a href="https://api.solved.ac/v2/auth?prev=%2F"><i class="material-icons">person</i></a></div></div></div><div class="Headerstyles__TopBarNavigationFader-aisgi1-14 ljbAQa"><div class="Headerstyles__TopBarMenuFader-aisgi1-16 pwNoP"></div></div><div class="Headerstyles__NavigationCompact-aisgi1-3 jIFOPq"><i class="material-icons primary" style="cursor:pointer">arrow_back</i><span class="Headerstyles__SiteTitle-aisgi1-4 hBPAfb">tag:math</span><a href="/"></a><div class="Headerstyles__TopBarInformation-aisgi1-19 dBCqXq"><a href="/"><i class="material-icons">home</i></a><i class="material-icons">search</i><i class="material-icons">expand_more</i></div></div><div class="Headerstyles__TopBarNavigationFader-aisgi1-14 Headerstyles__TopBarCompactNavigationFader-aisgi1-15 isTmyU"><div class="Headerstyles__TopBarCompactMenuFader-aisgi1-17 eKitDY"><nav class="Headerstyles__SitemapCompact-aisgi1-8 jBcGHn"><div class="Headerstyles__InformationCompact-aisgi1-9 haklhT"><a class="nounderline" href="https://api.solved.ac/v2/auth?prev=%2F"><div id="topbar_compact_information"><div class="Headerstyles__ProfileCompact-aisgi1-10 dBUpqv"><span><i class="material-icons">person</i><br/>BOJ로 로그인</span></div></div></a></div><nav><ul><li><input id="nav-problems" style="display:none" type="checkbox"/><label for="nav-problems"><span>문제</span></label><ul><li><a href="/problems/level">레벨</a></li><li><a href="/problems/tags">태그</a></li><li><a href="/search">검색</a></li><li><a href="/class">CLASS</a></li><li><a href="/problems/calculate">경험치 계산기</a></li></ul></li><li><input id="nav-contribute" style="display:none" type="checkbox"/><label for="nav-contribute"><span>기여</span></label><ul><li><a href="/guideline">가이드라인</a></li></ul></li><li><input id="nav-ranking" style="display:none" type="checkbox"/><label for="nav-ranking"><span>랭킹</span></label><ul><li><a href="/ranking/tier">티어</a></li><li><a href="/ranking/class">CLASS</a></li><li><a href="/ranking/contribution">기여</a></li><li><a href="/ranking/o">단체</a></li></ul></li><li><input id="nav-information" style="display:none" type="checkbox"/><label for="nav-information"><span>정보</span></label><ul><li><a href="/faq">자주 묻는 질문</a></li><li><a href="/rules">이용 규칙</a></li><li><a href="/redeem">코드 교환</a></li><li><a href="/slack">Slack</a></li><li><a href="/update_log">업데이트 로그</a></li></ul></li></ul></nav></nav></div></div><div class="Headerstyles__SearchFader-aisgi1-18 bhkGgc"><div class="SearchBarstyles__MainSearchContainer-avpdwf-0 bjWFeR"><div class="SearchBarstyles__MainSearch-avpdwf-2 wIJGj"><i class="SearchBarstyles__SearchIcLeft-avpdwf-3 gUFSOa material-icons">search</i><input autocomplete="off" type="text" value=""/><label for="top_bar_s ...

# %%
div1 = body[0].select('.StickyTable__Row-akg1ak-2')
print(len(div1))
for i in range(1, len(div1)+1): 
    print(div1[i])
div2 = div1[1]
print(div2)
# Out:
# 101
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/
</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">278</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">3.77</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1494"><img alt="Diamond V" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/21.svg"/> <span>1494</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1494"><span>절댓값 수열</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">56</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">5.29</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1500"><img alt="Silver I" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/10.svg"/> <span>1500</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1500"><span>최대 곱</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">619</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">1.81</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1521"><img alt="Platinum IV" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/17.svg"/> <span>1521</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1521"><span>랜덤 소트</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">75</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">1.63</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1529"><img alt="Platinum V" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/16.svg"/> <span>1529</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1529"><span>동민 수열</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">28</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">3.36</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1533"><img alt="Platinum IV" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/17.svg"/> <span>1533</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1533"><span>길의 개수</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">177</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">2.90</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1541"><img alt="Silver II" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/9.svg"/> <span>1541</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1541"><span>잃어버린 괄호</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">5,870</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">2.05</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1546"><img alt="Bronze I" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/5.svg"/> <span>1546</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1546"><span>평균</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">27,897</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">2.05</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1550"><img alt="Bronze V" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/1.svg"/> <span>1550</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1550"><span>16진수</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">4,532</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">1.47</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1551"><img alt="Bronze II" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/4.svg"/> <span>1551</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1551"><span>수열의 변화</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">1,172</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">1.83</div></div></div>
# <div class="StickyTable__Row-akg1ak-2 gwdwRc sticky-table-row"><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span><a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1554"><img alt="Diamond V" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/21.svg"/> <span>1554</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><span style="white-space:break-spaces"><a class="hover_underline" href="https://www.acmicpc.net/problem/1554"><span>나무 심기</span></a></span></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">6</div></div><div class="StickyTable__Cell-akg1ak-1 gWviaL sticky-table-cell"><div class="TabularFigures__TabularFiguresStyle-ved8ab-0 dlxNMM">3.83</div></div></div>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-114-f791f09521b1> in <module>
#       2 print(len(div1))
#       3 for i in range(1, len(div1)+1):
# ----> 4     print(div1[i])
#       5 div2 = div1[1]
#       6 print(div2)
#
# IndexError: list index out of range

# %%
div3 = div2.select('a')
print(div3)
div4 = div3[0]['href']
print(div4)
div5 = div3[0].select('img')[0]['alt']
print(div5)
div6 = div3[0].select('span')[0]
print("?>" + div6.text)
div7 = div3[1].select('span')[0]
print(div7.text)
div8 = div2.select('.TabularFigures__TabularFiguresStyle-ved8ab-0')
print(div8[0].text)
num = div8[0].text.replace(",","")
print((int)(num))
print(div8[1].text)
print((float)(div8[1].text))
# Out:
# [<a class="ProblemInline__ProblemStyle-cvf1lm-0 gLFkLK" href="https://www.acmicpc.net/problem/1000"><img alt="Bronze V" class="TierBadge__TierBadgeStyle-bguxxi-0 gPFKEd" src="https://static.solved.ac/tier_small/1.svg"/> <span>1000</span></a>, <a class="hover_underline" href="https://www.acmicpc.net/problem/1000"><span>A+B</span></a>]
# https://www.acmicpc.net/problem/1000
# Bronze V
# ?>1000
# A+B
# 98,776
# 98776
# 2.26
# 2.26

# %%
userlist = []
for t in range(1,81):
    url = "https://solved.ac/ranking/tier?page="+repr(t)
    print(t)
    try:
      headers = {'User-Agent':'Chrome/66.0.3359.181'}
      rew = req.Request(url,headers=headers)
      html = req.urlopen(rew)
    
    except HTTPError as e:
        err = e.read()
        code = e.getcode()
    source = html.read()
    html.close()
    soup = BeautifulSoup(source,"html.parser")
    body = soup.select('body')
    div = body[0].select('div b')
    for j in range(1,len(div)-1,2):
        print(div[j].string)
        userlist.append(div[j].string)
